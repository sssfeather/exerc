# %% [markdown]
# ***note:***
# ```
# dataselect -Ps -A /SDS/%Y/%n/%s/%c.D/%n.%s.%l.%c.D.%Y.%j $file
# ```

# %%
from obspy.clients.filesystem.sds import Client
from obspy.core.utcdatetime import UTCDateTime
client = Client("../data/SDS")

# %%
nslc = client.get_all_nslc(sds_type=None, datetime=None)
for n in nslc:
    print(n)
# Out:
# ('BJ', 'CIQ', '00', 'BHE')
# ('BJ', 'CIQ', '00', 'BHN')
# ('BJ', 'CIQ', '00', 'BHZ')
# ('BJ', 'CIQ', '01', 'BNE')
# ('BJ', 'CIQ', '01', 'BNN')
# ('BJ', 'CIQ', '01', 'BNZ')
# ('BJ', 'DHC', '00', 'BHE')
# ('BJ', 'DHC', '00', 'BHN')
# ('BJ', 'DHC', '00', 'BHZ')
# ('BJ', 'FHY', '00', 'BHE')
# ('BJ', 'FHY', '00', 'BHN')
# ('BJ', 'FHY', '00', 'BHZ')
# ('BJ', 'JIZ', '00', 'SHE')
# ('BJ', 'JIZ', '00', 'SHN')
# ('BJ', 'JIZ', '00', 'SHZ')
# ('BJ', 'JIZ', '01', 'BNE')
# ('BJ', 'JIZ', '01', 'BNN')
# ('BJ', 'JIZ', '01', 'BNZ')
# ('BJ', 'LBG', '00', 'BHE')
# ('BJ', 'LBG', '00', 'BHN')
# ('BJ', 'LBG', '00', 'BHZ')
# ('BJ', 'LLM', '00', 'BHE')
# ('BJ', 'LLM', '00', 'BHN')
# ('BJ', 'LLM', '00', 'BHZ')
# ('BJ', 'LQS', '00', 'BHE')
# ('BJ', 'LQS', '00', 'BHN')
# ('BJ', 'LQS', '00', 'BHZ')
# ('BJ', 'MAF', '00', 'SHE')
# ('BJ', 'MAF', '00', 'SHN')
# ('BJ', 'MAF', '00', 'SHZ')
# ('BJ', 'MAF', '01', 'BNE')
# ('BJ', 'MAF', '01', 'BNN')
# ('BJ', 'MAF', '01', 'BNZ')
# ('BJ', 'MDY', '00', 'BHE')
# ('BJ', 'MDY', '00', 'BHN')
# ('BJ', 'MDY', '00', 'BHZ')
# ('BJ', 'MIY', '00', 'BHE')
# ('BJ', 'MIY', '00', 'BHN')
# ('BJ', 'MIY', '00', 'BHZ')
# ('BJ', 'NKY', '00', 'BHE')
# ('BJ', 'NKY', '00', 'BHN')
# ('BJ', 'NKY', '00', 'BHZ')
# ('BJ', 'NLS', '00', 'SHE')
# ('BJ', 'NLS', '00', 'SHN')
# ('BJ', 'NLS', '00', 'SHZ')
# ('BJ', 'NLS', '01', 'BNE')
# ('BJ', 'NLS', '01', 'BNN')
# ('BJ', 'NLS', '01', 'BNZ')
# ('BJ', 'SFS', '00', 'BHE')
# ('BJ', 'SFS', '00', 'BHN')
# ('BJ', 'SFS', '00', 'BHZ')
# ('BJ', 'SSL', '00', 'BHE')
# ('BJ', 'SSL', '00', 'BHN')
# ('BJ', 'SSL', '00', 'BHZ')
# ('BJ', 'TIT', '00', 'SHE')
# ('BJ', 'TIT', '00', 'SHN')
# ('BJ', 'TIT', '00', 'SHZ')
# ('BJ', 'TST', '00', 'BHE')
# ('BJ', 'TST', '00', 'BHN')
# ('BJ', 'TST', '00', 'BHZ')
# ('BJ', 'XBZ', '00', 'BHE')
# ('BJ', 'XBZ', '00', 'BHN')
# ('BJ', 'XBZ', '00', 'BHZ')
# ('BJ', 'XIJ', '00', 'BHE')
# ('BJ', 'XIJ', '00', 'BHN')
# ('BJ', 'XIJ', '00', 'BHZ')
# ('BJ', 'ZHT', '00', 'BHE')
# ('BJ', 'ZHT', '00', 'BHN')
# ('BJ', 'ZHT', '00', 'BHZ')

# %%
stns = client.get_all_stations()
for s in stns:
    print(s)
# Out:
# ('BJ', 'CIQ')
# ('BJ', 'DHC')
# ('BJ', 'FHY')
# ('BJ', 'JIZ')
# ('BJ', 'LBG')
# ('BJ', 'LLM')
# ('BJ', 'LQS')
# ('BJ', 'MAF')
# ('BJ', 'MDY')
# ('BJ', 'MIY')
# ('BJ', 'NKY')
# ('BJ', 'NLS')
# ('BJ', 'SFS')
# ('BJ', 'SSL')
# ('BJ', 'TIT')
# ('BJ', 'TST')
# ('BJ', 'XBZ')
# ('BJ', 'XIJ')
# ('BJ', 'ZHT')

# %%
net="BJ"
sta="DHC" 
loc="*" 
cha="BH?" 
stime=UTCDateTime("2018-07-20T16:00:04")
etime=UTCDateTime("2018-08-22T16:00:02")

# %%
avaper = client.get_availability_percentage(network=net, 
                                            station=sta, 
                                            location=loc, 
                                            channel=cha, 
                                            starttime=stime, 
                                            endtime=etime)
print(avaper)
# Out:
# (0.6490921745876645, 19)

# %%
wf = client.get_waveforms(network=net, 
                          station=sta, 
                          location=loc, 
                          channel=cha, 
                          starttime=stime, 
                          endtime=etime)
print(wf.__str__(extended=True))
# Out:
# 21 Trace(s) in Stream:
# BJ.DHC.00.BHE | 2018-07-31T16:00:02.690000Z - 2018-08-08T05:00:18.990000Z | 100.0 Hz, 65161631 samples
# BJ.DHC.00.BHE | 2018-08-08T05:00:23.000000Z - 2018-08-12T14:53:56.990000Z | 100.0 Hz, 38121400 samples
# BJ.DHC.00.BHE | 2018-08-12T14:55:00.000000Z - 2018-08-12T15:32:58.990000Z | 100.0 Hz, 227900 samples
