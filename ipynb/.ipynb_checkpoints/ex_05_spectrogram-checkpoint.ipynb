# %% [markdown]
# ### 谱计算

# %% [markdown]
# ### 0.导入函数库

# %%
# %matplotlib inline
from obspy.core import read
from obspy import read_inventory
from obspy.imaging.cm import pqlx
from obspy.signal.invsim import cosine_taper 
from obspy.signal.filter import lowpass
from obspy.core import UTCDateTime
from obspy.signal import PPSD
from matplotlib import rcParams
import numpy as np
import matplotlib.pylab as plt
# plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = 15, 7
rcParams["figure.subplot.hspace"] = (0.5)

# %% [markdown]
# ### 1.瞬时谱计算
# ****
# 瞬时谱是一种可视化方法，可以同时展示信号在时间和频率上的特征。通过谱图，可以观察到地震信号的频率成分随时间的变化情况，从而更好地理解地震事件的动态过程。
# ****

# %%
# matplotlib 计算谱图的函数
st = read("../data/spect_trace.mseed")
# 去仪器响应
inv = read_inventory("../data/GR.WET.xml")
st.remove_response(output="VEL", inventory=inv)
st.detrend('linear')
st.detrend('demean')

tr = st[0]
NFFT = 256     # 谱图窗长度
noverlap = 50  # 滑动窗口重叠点数量，必须小于NFFT
xstart = 0     # X轴起始点
xend = 21627   # 信号长度，单位为秒

# 绘图
ax1 = plt.subplot(211)
plt.plot(tr.times(), tr.data, linewidth=0.5, color="#5499C7")
plt.ylabel('velocity [m/s]')

plt.subplot(212, sharex=ax1)
# Pxx： 表示瞬时功率的二维数组，其中行表示时间段，列表示频率
# freqs： 频率向量
# bins： 计算功率的时间区间的中心点
# im： matplotlib.image.AxesImage实例
Pxx, freqs, bins, im = plt.specgram(tr.data, NFFT=NFFT, Fs=tr.stats.sampling_rate, 
                                    noverlap=noverlap, cmap=pqlx)
print(Pxx, freqs, bins)
plt.ylabel('frequency [Hz]')
plt.xlabel('time [sec]')

# 调整Y轴范围
plt.ylim(0,5)
plt.xlim(xstart, xend)
plt.show()
# Out:
# [[1.76306503e-10 1.67835097e-10 1.59788405e-10 ... 1.14074938e-08
#   1.13911521e-08 1.14709441e-08]
#  [8.93528612e-11 8.47546353e-11 8.08873621e-11 ... 5.77571833e-09
#   5.76628062e-09 5.80159984e-09]
#  [1.32083770e-15 2.19217966e-15 1.26836784e-15 ... 4.61049256e-14
#   6.49745604e-14 3.53132892e-14]
#  ...
#  [5.88053994e-25 1.18801614e-23 7.92001587e-24 ... 1.09119112e-22
#   3.01932783e-23 1.00821960e-24]
#  [7.75857776e-25 2.62560164e-24 6.49094147e-23 ... 2.50191763e-22
#   6.67146383e-23 8.83059674e-24]
#  [3.25582662e-24 6.80391298e-24 5.37204931e-24 ... 6.17710016e-23
#   7.27357065e-24 1.89697729e-23]] [ 0.        0.078125  0.15625   0.234375  0.3125    0.390625  0.46875
#   0.546875  0.625     0.703125  0.78125   0.859375  0.9375    1.015625
#   1.09375   1.171875  1.25      1.328125  1.40625   1.484375  1.5625
#   1.640625  1.71875   1.796875  1.875     1.953125  2.03125   2.109375
#   2.1875    2.265625  2.34375   2.421875  2.5       2.578125  2.65625
#   2.734375  2.8125    2.890625  2.96875   3.046875  3.125     3.203125
#   3.28125   3.359375  3.4375    3.515625  3.59375   3.671875  3.75
#   3.828125  3.90625   3.984375  4.0625    4.140625  4.21875   4.296875
#   4.375     4.453125  4.53125   4.609375  4.6875    4.765625  4.84375
#   4.921875  5.        5.078125  5.15625   5.234375  5.3125    5.390625
#   5.46875   5.546875  5.625     5.703125  5.78125   5.859375  5.9375
#   6.015625  6.09375   6.171875  6.25      6.328125  6.40625   6.484375
#   6.5625    6.640625  6.71875   6.796875  6.875     6.953125  7.03125
#   7.109375  7.1875    7.265625  7.34375   7.421875  7.5       7.578125
#   7.65625   7.734375  7.8125    7.890625  7.96875   8.046875  8.125
#   8.203125  8.28125   8.359375  8.4375    8.515625  8.59375   8.671875
#   8.75      8.828125  8.90625   8.984375  9.0625    9.140625  9.21875
#   9.296875  9.375     9.453125  9.53125   9.609375  9.6875    9.765625
#   9.84375   9.921875 10.      ] [6.40000e+00 1.67000e+01 2.70000e+01 ... 2.15643e+04 2.15746e+04
#  2.15849e+04]

# %%
# Obspy 计算谱图的函数
st = read("../data/spect_trace.mseed")
tr = st[0]

ax1 = plt.subplot(211)
plt.plot(tr.times(), tr.data, linewidth=0.5, color="#5499C7")
plt.ylabel('Counts')

ax2 = plt.subplot(212, sharex=ax1)
fig = tr.spectrogram(wlen=100, per_lap=0.5, dbscale=True, cmap=pqlx, axes=ax2, show=False)
plt.xlabel('time [sec]')
plt.ylabel('velocity [m/s]')
plt.ylim(0,1.0)
# Out:
# (0.0, 1.0)

# %%
# Obspy 计算谱图的函数
st = read("../data/test_trace.mseed")
tr = st[0]

ax1 = plt.subplot(211)
plt.plot(tr.times(), tr.data, linewidth=0.5, color="#5499C7")
plt.ylabel('Counts')

ax2 = plt.subplot(212, sharex=ax1)
fig = tr.spectrogram(per_lap=0.8, wlen=1, dbscale=True, axes=ax2, mult=10.0, cmap=pqlx)
plt.xlabel('time [sec]')
plt.ylabel('velocity [m/s]')
plt.ylim(0,50)
# Out:
# (0.0, 50.0)

# %%
st = read("../data/BJ.DHC.00.BHZ.20180820031801.mseed")
inv = read_inventory("../data/BJ.XML")

print(st)
print(inv)
inv.plot(projection="ortho");
# Out:
# 6 Trace(s) in Stream:
# BJ.DHC.00.BHZ | 2018-08-19T19:18:01.000000Z - 2018-08-19T20:14:58.990000Z | 100.0 Hz, 341800 samples
# BJ.DHC.00.BHZ | 2018-08-19T20:37:07.000000Z - 2018-08-19T22:25:26.990000Z | 100.0 Hz, 650000 samples
# BJ.DHC.00.BHZ | 2018-08-19T22:24:26.000000Z - 2018-08-19T22:24:26.990000Z | 100.0 Hz, 100 samples
# BJ.DHC.00.BHZ | 2018-08-19T22:25:27.000000Z - 2018-08-20T08:29:17.990000Z | 100.0 Hz, 3623100 samples
# BJ.DHC.00.BHZ | 2018-08-20T08:28:17.000000Z - 2018-08-20T08:28:17.990000Z | 100.0 Hz, 100 samples
# BJ.DHC.00.BHZ | 2018-08-20T08:29:18.000000Z - 2018-08-20T16:00:02.490000Z | 100.0 Hz, 2704450 samples
# Inventory created at 2020-07-29T07:10:36.522072Z
# 	Created by: ObsPy 1.1.1
# 		    https://www.obspy.org
# 	Sending institution: ObsPy's obspy.io.xseed version 1.1.1
# 	Contains:
# 		Networks (1):
# 			BJ
# 		Stations (26):
# 			BJ.CIQ (00)
# 			BJ.DAX (00)
# 			BJ.DHC (00)
# 			BJ.DSQ (00)
# 			BJ.FHY (00)
# 			BJ.JIZ (00)
# 			BJ.LBG (00)
# 			BJ.LBP (00)
# 			BJ.LLM (00)
# 			BJ.LQS (00)
# 			BJ.MAF (00)
# 			BJ.MDY (00)
# 			BJ.MIY (00)
# 			BJ.NKY (00)
# 			BJ.NLS (00)
# 			BJ.NSC (00)
# 			BJ.SFS (00)
# 			BJ.SSL (00)
# 			BJ.SZL (00)
# 			BJ.TIT (00)
# 			BJ.TST (00)
# 			BJ.XBZ (00)
# 			BJ.XIJ (00)
# 			BJ.YAZ (00)
# 			BJ.ZHT (00)
# 			BJ.ZKD (00)
# 		Channels (78):
# 			BJ.CIQ.00.BHZ, BJ.CIQ.00.BHN, BJ.CIQ.00.BHE, BJ.DAX.00.BHZ,
# 			BJ.DAX.00.BHN, BJ.DAX.00.BHE, BJ.DHC.00.BHZ, BJ.DHC.00.BHN,
# 			BJ.DHC.00.BHE, BJ.DSQ.00.SHZ, BJ.DSQ.00.SHN, BJ.DSQ.00.SHE,
# 			BJ.FHY.00.BHZ, BJ.FHY.00.BHN, BJ.FHY.00.BHE, BJ.JIZ.00.SHZ,
# 			BJ.JIZ.00.SHN, BJ.JIZ.00.SHE, BJ.LBG.00.BHZ, BJ.LBG.00.BHN,
# 			BJ.LBG.00.BHE, BJ.LBP.00.BHZ, BJ.LBP.00.BHN, BJ.LBP.00.BHE,
# 			BJ.LLM.00.BHZ, BJ.LLM.00.BHN, BJ.LLM.00.BHE, BJ.LQS.00.BHZ,
# 			BJ.LQS.00.BHN, BJ.LQS.00.BHE, BJ.MAF.00.SHZ, BJ.MAF.00.SHN,
# 			BJ.MAF.00.SHE, BJ.MDY.00.BHZ, BJ.MDY.00.BHN, BJ.MDY.00.BHE,
# 			BJ.MIY.00.BHZ, BJ.MIY.00.BHN, BJ.MIY.00.BHE, BJ.NKY.00.BHZ,
# 			BJ.NKY.00.BHN, BJ.NKY.00.BHE, BJ.NLS.00.SHZ, BJ.NLS.00.SHN,
# 			BJ.NLS.00.SHE, BJ.NSC.00.BHZ, BJ.NSC.00.BHN, BJ.NSC.00.BHE,
# 			BJ.SFS.00.BHZ, BJ.SFS.00.BHN, BJ.SFS.00.BHE, BJ.SSL.00.BHZ,
# 			BJ.SSL.00.BHN, BJ.SSL.00.BHE, BJ.SZL.00.BHZ, BJ.SZL.00.BHN,
# 			BJ.SZL.00.BHE, BJ.TIT.00.SHZ, BJ.TIT.00.SHN, BJ.TIT.00.SHE,
# 			BJ.TST.00.BHZ, BJ.TST.00.BHN, BJ.TST.00.BHE, BJ.XBZ.00.BHZ,
# 			BJ.XBZ.00.BHN, BJ.XBZ.00.BHE, BJ.XIJ.00.BHZ, BJ.XIJ.00.BHN,
# 			BJ.XIJ.00.BHE, BJ.YAZ.00.SHZ, BJ.YAZ.00.SHN, BJ.YAZ.00.SHE,
# 			BJ.ZHT.00.BHZ, BJ.ZHT.00.BHN, BJ.ZHT.00.BHE, BJ.ZKD.00.BHZ,
# 			BJ.ZKD.00.BHN, BJ.ZKD.00.BHE
# /home/muly/.local/lib/python3.11/site-packages/obspy/imaging/maps.py:37: UserWarning: Cartopy not installed, map plots will not work.
#   warnings.warn(msg)
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[24], line 6
#       4 print(st)
#       5 print(inv)
# ----> 6 inv.plot(projection="ortho");
#
# File ~/.local/lib/python3.11/site-packages/obspy/core/inventory/inventory.py:1006, in Inventory.plot(self, projection, resolution, continent_fill_color, water_fill_color, marker, size, label, color, color_per_network, colormap, legend, time, show, outfile, method, fig, **kwargs)
#    1003 if not label:
#    1004     labels = None
# -> 1006 fig = plot_map(method, lons, lats, size, colors, labels,
#    1007                projection=projection, resolution=resolution,
#    1008                continent_fill_color=continent_fill_color,
#    1009                water_fill_color=water_fill_color,
#    1010                colormap=None, colorbar=False, marker=marker,
#    1011                title=None, show=False, fig=fig, **kwargs)
#    1013 if legend is not None and color_per_network:
#    1014     ax = fig.axes[0]
#
# File ~/.local/lib/python3.11/site-packages/obspy/imaging/maps.py:502, in plot_map(method, *args, **kwargs)
#     500         return plot_cartopy(*args, **kwargs)
#     501     else:
# --> 502         raise ImportError('Cartopy could not be imported.')
#     503 elif method == 'cartopy':
#     504     if not HAS_CARTOPY:
#
# ImportError: Cartopy could not be imported.
